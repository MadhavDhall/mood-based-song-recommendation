# %%
print("Hello Madhav Dhall Ji")
# Out:
# Hello Madhav Dhall Ji

# %%
import nltk
nltk.download('punkt_tab')
import re
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

text = "Absolutely loved the new movie! It was fantastic."

# Remove punctuation and convert to lowercase
text_cleaned = re.sub(r'[^\w\s]', '', text.lower())

# Tokenize and remove stopwords
tokens = word_tokenize(text_cleaned)
filtered_tokens = [word for word in tokens if word not in stopwords.words('english')]
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/madhavdhall/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
print("Filtered Tokens:", filtered_tokens)
# Out:
# Filtered Tokens: ['absolutely', 'loved', 'new', 'movie', 'fantastic']

# %%
from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer()
X = vectorizer.fit_transform([' '.join(filtered_tokens)])  # Treat as one document
print(X)
print("Feature Names:", vectorizer.get_feature_names_out())
# Out:
#   (np.int32(0), np.int32(0))	1
#   (np.int32(0), np.int32(2))	1
#   (np.int32(0), np.int32(4))	1
#   (np.int32(0), np.int32(3))	1
#   (np.int32(0), np.int32(1))	1
# Feature Names: ['absolutely' 'fantastic' 'loved' 'movie' 'new']

# %%
from sklearn.naive_bayes import MultinomialNB

y = ['positive'] # Training label
clf = MultinomialNB()
clf.fit(X, y)

print("Trained Naive Bayes Classifier")
print("Class Labels:", clf.classes_)
# Predicting the sentiment of the same text
# Out:
# Trained Naive Bayes Classifier
# Class Labels: ['positive']

# %%
emotion_data = [("Loved the surprise party!", "joy"),
("This traffic is infuriating.", "anger"),
("Feeling down on a rainy day.", "sadness")]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import SVC

X_emotion = [data[0] for data in emotion_data]
y_emotion = [data[1] for data in emotion_data]

vectorizer_emotion = TfidfVectorizer()
X_emotion_vec = vectorizer_emotion.fit_transform(X_emotion)

clf_emotion = SVC(kernel='linear')
clf_emotion.fit(X_emotion_vec, y_emotion)

new_text_emotion = "This success feels amazing!"
new_text_vec = vectorizer_emotion.transform([new_text_emotion])
predicted_emotion = clf_emotion.predict(new_text_vec)

print(X_emotion_vec, y_emotion)
print(predicted_emotion) # Output: [‘joy’]
# Out:
#   (np.int32(0), np.int32(5))	0.49999999999999994
#   (np.int32(0), np.int32(7))	0.49999999999999994
#   (np.int32(0), np.int32(9))	0.49999999999999994
#   (np.int32(0), np.int32(10))	0.49999999999999994
#   (np.int32(1), np.int32(3))	0.49999999999999994
#   (np.int32(1), np.int32(4))	0.49999999999999994
#   (np.int32(1), np.int32(11))	0.49999999999999994
#   (np.int32(1), np.int32(12))	0.49999999999999994
#   (np.int32(2), np.int32(0))	0.44721359549995787
#   (np.int32(2), np.int32(1))	0.44721359549995787
#   (np.int32(2), np.int32(2))	0.44721359549995787
#   (np.int32(2), np.int32(6))	0.44721359549995787
#   (np.int32(2), np.int32(8))	0.44721359549995787 ['joy', 'anger', 'sadness']
# ['anger']

# %%
# %pip install pandas

import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# read the dataset
df = pd.read_csv('./data/tweet_emotions.csv')

X = df.iloc[:, 2] #get all the sentences
y = df.iloc[:, 1] # get the emotions associated with the sentences

print(X)
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# 0        @tiffanylue i know  i was listenin to bad habi...
# 1        Layin n bed with a headache  ughhhh...waitin o...
# 2                      Funeral ceremony...gloomy friday...
# 3                     wants to hang out with friends SOON!
# 4        @dannycastillo We want to trade with someone w...
#                                ...
# 39995                                     @JohnLloydTaylor
# 39996                       Happy Mothers Day  All my love
# 39997    Happy Mother's Day to all the mommies out ther...
# 39998    @niariley WASSUP BEAUTIFUL!!! FOLLOW ME!!  PEE...
# 39999    @mopedronin bullet train from tokyo    the gf ...
# Name: content, Length: 40000, dtype: object

# %%
print(y.unique(),"\n", y.unique().size)  # Print unique labels and length of unique labels
print(y)
# Out:
# ['empty' 'sadness' 'enthusiasm' 'neutral' 'worry' 'surprise' 'love' 'fun'
#  'hate' 'happiness' 'boredom' 'relief' 'anger']
#  13
# 0             empty
# 1           sadness
# 2           sadness
# 3        enthusiasm
# 4           neutral
#             ...
# 39995       neutral
# 39996          love
# 39997          love
# 39998     happiness
# 39999          love
# Name: sentiment, Length: 40000, dtype: object

# %%
# split the dataset
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=0)

print(X_train, X_test, y_train, y_test)
# Out:
# 21370    @Lizzi_85 Aaaargh help -it's a conspiracy LOL!...
# 2470                      how i wish the result IS true...
# 13767    @sydneetaylor ur welcome sweetie . Anytime . I...
# 13316    can u believe the architect who planned a tar-...
# 26374    @JoLoPe I liked it.  Did you record it yoursel...
#                                ...
# 20757                                @jonorossi in between
# 32103    @_Bella_Cullen13 @RosalieHCullen @Esme_Cullen2...
# 30403                              @DucCat900 pic, please.
# 21243    @puppaz that really sucks I feel bad for you a...
# 2732     @_refugee_ /me gets &quot;Your video will star...
# Name: content, Length: 32000, dtype: object 12836    @aaronhoskins I fucking miss that band so so much
# 10913                                      @shradhac uh oh
# 4214                  So effing tired  http://bit.ly/e0ZFz
# 8198                 @Shooz1 ok ok mam ... i was jus angry
# 31403          Live from New York, it's Justin Timberlake!
# ...

# %%
# checking the length of the training and testing data
print("Length of training data:", len(X_train))
print("Length of testing data:", len(X_test))
# Out:
# Length of training data: 32000
# Length of testing data: 8000

# %%
# now Feature Extraction and Emotion Classification from the dataset:

# Remove punctuation and convert to lowercase, also remove words containing '@' because they are usually usernames
X_train_cleaned = [' '.join(re.sub(r'[^\w\s]', '', word.lower()) for word in text.split() if '@' not in word) for text in X_train]


# Tokenize and remove stopwords
X_train_tokenize = [word_tokenize(text) for text in X_train_cleaned]

print("First training text:", X_train.iloc[0]) # Original first training text
print("cleaned", X_train_cleaned[0]) # cleaned first training text (Removed punctuation and converted to lowercase)
print(X_train_tokenize[0]) # Tokenized first training text

# removing stop words
X_train_filtered = [' '.join([word for word in tokens if word not in stopwords.words('english')]) for tokens in X_train_tokenize]
print("Filtered Tokens:", X_train_filtered[0]) # Filtered first training text (Removed stopwords)
# filtered_tokens = [word for word in tokens if word not in stopwords.words('english')]
# Out:
# First training text: @Lizzi_85 Aaaargh help -it's a conspiracy LOL! How are you today Lizzi?
# cleaned aaaargh help its a conspiracy lol how are you today lizzi
# ['aaaargh', 'help', 'its', 'a', 'conspiracy', 'lol', 'how', 'are', 'you', 'today', 'lizzi']
# Filtered Tokens: aaaargh help conspiracy lol today lizzi

# %%
# now Feature Extraction and Emotion Classification from the dataset:

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import SVC

vectorizer_train = TfidfVectorizer()
X_emotion_vec = vectorizer_emotion.fit_transform(X_train)

clf_emotion = SVC(kernel='linear')
clf_emotion.fit(X_emotion_vec, y_train)
# Out:
# SVC(kernel='linear')

# %%
new_text_vec = vectorizer_emotion.transform(X_test)
predicted_emotion = clf_emotion.predict(new_text_vec)
print("Predicted Emotions for Test Set:", predicted_emotion)
# Evaluating the model
# Out:
# Predicted Emotions for Test Set: ['sadness' 'worry' 'neutral' ... 'worry' 'neutral' 'sadness']

# %%
print(y_test[:5])  # True emotions for the test set
print("First 5 Predicted Emotions:", predicted_emotion[:5])
from sklearn.metrics import accuracy_score, classification_report
accuracy = accuracy_score(y_test, predicted_emotion)
print("Accuracy of Emotion Classification:", accuracy)
print("Classification Report:\n", classification_report(y_test, predicted_emotion))
# Out:
# 12836    sadness
# 10913    neutral
# 4214     sadness
# 8198       empty
# 31403        fun
# Name: sentiment, dtype: object
# First 5 Predicted Emotions: ['sadness' 'worry' 'neutral' 'neutral' 'happiness']
# Accuracy of Emotion Classification: 0.356
# Classification Report:
#                precision    recall  f1-score   support
#
#        anger       0.00      0.00      0.00        19
#      boredom       0.00      0.00      0.00        37
#        empty       0.00      0.00      0.00       147
#   enthusiasm       0.00      0.00      0.00       147
#          fun       0.15      0.02      0.04       354
#    happiness       0.34      0.42      0.38      1052
#         hate       0.34      0.15      0.21       251
#         love       0.51      0.41      0.46       780
#      neutral       0.35      0.51      0.41      1743
#       relief       0.29      0.02      0.04       292
#      sadness       0.38      0.25      0.30      1062
# ...

# %%
# above model has very low accuracy of 35.6%

# lets try training the model on filtered_tokens
vectorizer_train = TfidfVectorizer()
X_emotion_vec = vectorizer_emotion.fit_transform(X_train_filtered)

clf_emotion = SVC(kernel='linear')
clf_emotion.fit(X_emotion_vec, y_train)
# Out:
# SVC(kernel='linear')

# %%
# now Feature Extraction and Emotion Classification from the dataset:

# Remove punctuation and convert to lowercase, also remove words containing '@' because they are usually usernames
X_test_cleaned = [' '.join(re.sub(r'[^\w\s]', '', word.lower()) for word in text.split() if '@' not in word) for text in X_test]


# Tokenize and remove stopwords
X_test_tokenize = [word_tokenize(text) for text in X_test_cleaned]

print("First training text:", X_test.iloc[0]) # Original first training text
print("cleaned", X_test_cleaned[0]) # cleaned first training text (Removed punctuation and converted to lowercase)
print(X_test_tokenize[0]) # Tokenized first training text

# removing stop words
X_test_filtered = [' '.join([word for word in tokens if word not in stopwords.words('english')]) for tokens in X_test_tokenize]
print("Filtered Tokens:", X_test_filtered[0]) # Filtered first training text (Removed stopwords)
# Out:
# First training text: @aaronhoskins I fucking miss that band so so much
# cleaned i fucking miss that band so so much
# ['i', 'fucking', 'miss', 'that', 'band', 'so', 'so', 'much']
# Filtered Tokens: fucking miss band much

# %%
new_text_vec = vectorizer_emotion.transform(X_test_filtered)
predicted_emotion = clf_emotion.predict(new_text_vec)
print("Predicted Emotions for Test Set:", predicted_emotion)
# Evaluating the model
# Out:
# Predicted Emotions for Test Set: ['sadness' 'worry' 'neutral' ... 'worry' 'neutral' 'happiness']

# %%
print(y_test[:5])  # True emotions for the test set
print("First 5 Predicted Emotions:", predicted_emotion[:5])
from sklearn.metrics import accuracy_score, classification_report
accuracy = accuracy_score(y_test, predicted_emotion)
print("Accuracy of Emotion Classification:", accuracy)
print("Classification Report:\n", classification_report(y_test, predicted_emotion))
# Out:
# 12836    sadness
# 10913    neutral
# 4214     sadness
# 8198       empty
# 31403        fun
# Name: sentiment, dtype: object
# First 5 Predicted Emotions: ['sadness' 'worry' 'neutral' 'neutral' 'happiness']
# Accuracy of Emotion Classification: 0.347
# Classification Report:
#                precision    recall  f1-score   support
#
#        anger       0.00      0.00      0.00        19
#      boredom       0.00      0.00      0.00        37
#        empty       0.00      0.00      0.00       147
#   enthusiasm       0.00      0.00      0.00       147
#          fun       0.15      0.03      0.04       354
#    happiness       0.33      0.37      0.35      1052
#         hate       0.36      0.15      0.21       251
#         love       0.53      0.41      0.46       780
#      neutral       0.34      0.57      0.42      1743
#       relief       0.21      0.03      0.05       292
#      sadness       0.38      0.24      0.29      1062
# ...

# %%
#above model has very low accuracy of 34.7%

#lets try using another dataset
# read the dataset
df_train= pd.read_csv('./emotionDetectionData/train.txt', sep=';')
df_test = pd.read_csv('./emotionDetectionData/test.txt', sep=';')
print(df_train.iloc[:, 0]) # get all the sentences
print(df_train.iloc[:, 1]) # get the emotions associated with the sentences

print(df_train.size, df_test.size) # Print the size of the datasets
# Out:
# 0        i can go from feeling so hopeless to so damned...
# 1         im grabbing a minute to post i feel greedy wrong
# 2        i am ever feeling nostalgic about the fireplac...
# 3                                     i am feeling grouchy
# 4        ive been feeling a little burdened lately wasn...
#                                ...
# 15994    i just had a very brief time in the beanbag an...
# 15995    i am now turning and i feel pathetic that i am...
# 15996                       i feel strong and good overall
# 15997    i feel like this was such a rude comment and i...
# 15998    i know a lot but i feel so stupid because i ca...
# Name: i didnt feel humiliated, Length: 15999, dtype: object
# 0        sadness
# 1          anger
# 2           love
# 3          anger
# 4        sadness
#           ...
# 15994    sadness
# 15995    sadness
# 15996        joy
# 15997      anger
# 15998    sadness
# Name: sadness, Length: 15999, dtype: object
# 31998 3998

# %%
X_train = df_train.iloc[:, 0] # get all the sentences
y_train = df_train.iloc[:, 1] # get the emotions associated with the sentences
X_test = df_test.iloc[:, 0] # get all the sentences
y_test = df_test.iloc[:, 1] # get the emotions associated with the sentences

print("Training Data Size:", len(X_train))
print("Testing Data Size:", len(X_test))

print(X_train)
print(y_train)
print(X_test)
print(y_test)

print("Unique Emotions in Training Set:", y_train.unique())
print("Unique Emotions in Testing Set:", y_test.unique())
# Out:
# Training Data Size: 15999
# Testing Data Size: 1999
# 0        i can go from feeling so hopeless to so damned...
# 1         im grabbing a minute to post i feel greedy wrong
# 2        i am ever feeling nostalgic about the fireplac...
# 3                                     i am feeling grouchy
# 4        ive been feeling a little burdened lately wasn...
#                                ...
# 15994    i just had a very brief time in the beanbag an...
# 15995    i am now turning and i feel pathetic that i am...
# 15996                       i feel strong and good overall
# 15997    i feel like this was such a rude comment and i...
# 15998    i know a lot but i feel so stupid because i ca...
# Name: i didnt feel humiliated, Length: 15999, dtype: object
# 0        sadness
# 1          anger
# 2           love
# 3          anger
# 4        sadness
#           ...
# 15994    sadness
# 15995    sadness
# 15996        joy
# 15997      anger
# 15998    sadness
# ...

# %%
vectorizer_emotion = TfidfVectorizer()
X_train_vec = vectorizer_emotion.fit_transform(X_train)

clf_emotion = SVC(kernel='linear')
clf_emotion.fit(X_train_vec, y_train)
# Out:
# SVC(kernel='linear')

# %%
X_test_vec = vectorizer_emotion.transform(X_test)
predicted_emotion = clf_emotion.predict(X_test_vec)
print("Predicted Emotions for Test Set:", predicted_emotion[:5])
print("True Emotions for Test Set:", y_test[:5])
# Out:
# Predicted Emotions for Test Set: ['sadness' 'sadness' 'joy' 'sadness' 'fear']
# True Emotions for Test Set: 0    sadness
# 1    sadness
# 2        joy
# 3    sadness
# 4       fear
# Name: sadness, dtype: object

# %%
# now testing the accuracy of the model
from sklearn.metrics import accuracy_score, classification_report
accuracy = accuracy_score(y_test, predicted_emotion)
print("Accuracy of Emotion Classification:", accuracy)
print("Classification Report:\n", classification_report(y_test, predicted_emotion))
# Out:
# Accuracy of Emotion Classification: 0.8839419709854928
# Classification Report:
#                precision    recall  f1-score   support
#
#        anger       0.89      0.88      0.88       275
#         fear       0.84      0.86      0.85       224
#          joy       0.88      0.95      0.91       695
#         love       0.82      0.67      0.74       159
#      sadness       0.94      0.91      0.92       580
#     surprise       0.76      0.56      0.64        66
#
#     accuracy                           0.88      1999
#    macro avg       0.85      0.81      0.82      1999
# weighted avg       0.88      0.88      0.88      1999

# %%
# now testing some custom sentences from my side
custom_sentences = [
    "i am so happy to see you",
    "this is the worst day of my life damn so  bad",
    "i feel so excited about the upcoming event",
    "you are really annoying me right now",
    "i am so sad about the news i heard today",
    "ive been feeling a little burdened lately wasnt sure why that was",
    "i am sorry for u my dear friend",
    "never show me your face again",
    "i am so grateful for your help",]
custom_sentences_vec = vectorizer_emotion.transform(custom_sentences)
predicted_custom_emotions = clf_emotion.predict(custom_sentences_vec)
print("Predicted Emotions for Custom Sentences:", predicted_custom_emotions)

# this shows poor performance of the model on custom sentences
# need some better dataset for training the model
# Out:
# Predicted Emotions for Custom Sentences: ['joy' 'sadness' 'joy' 'joy' 'sadness' 'sadness' 'sadness' 'joy' 'joy']

# %%
# checking what val.txt file is 
val_df = pd.read_csv('./emotionDetectionData/val.txt', sep=';')
print("Validation Data Size:", len(val_df))
print("Validation Data Sample:\n", val_df.head())
# Out:
# Validation Data Size: 1999
# Validation Data Sample:
#    im feeling quite sad and sorry for myself but ill snap out of it soon  \
# 0  i feel like i am still looking at a blank canv...
# 1                     i feel like a faithful servant
# 2                  i am just feeling cranky and blue
# 3  i can have for a treat or if i am feeling festive
# 4  i start to feel more appreciative of what god ...
#
#    sadness
# 0  sadness
# 1     love
# 2    anger
# 3      joy
# 4      joy

# %%
predicted_emotion_val = clf_emotion.predict(vectorizer_emotion.transform(val_df.iloc[:, 0]))
print("Predicted Emotions for Validation Set:", predicted_emotion_val[:5])
print("True Emotions for Validation Set:", val_df.iloc[:, 1][:5])
# Evaluating the model on validation set
accuracy_val = accuracy_score(val_df.iloc[:, 1], predicted_emotion_val)
print("Accuracy of Emotion Classification on Validation Set:", accuracy_val)
# Out:
# Predicted Emotions for Validation Set: ['sadness' 'love' 'anger' 'joy' 'joy']
# True Emotions for Validation Set: 0    sadness
# 1       love
# 2      anger
# 3        joy
# 4        joy
# Name: sadness, dtype: object
# Accuracy of Emotion Classification on Validation Set: 0.8894447223611806

# %%
# now trying the third dataset
# read the dataset

df_train=pd.read_csv('./dataset3/training.csv')
df_test=pd.read_csv('./dataset3/test.csv')

X_train = df_train.iloc[:, 0]  # get all the sentences
y_train = df_train.iloc[:, 1]  # get the emotions associated with the sentences
X_test = df_test.iloc[:, 0]  # get all the sentences
y_test = df_test.iloc[:, 1]  # get the emotions associated with the sentences

print("Training Data Size:", len(X_train))
print("Testing Data Size:", len(X_test))

print(X_train)
print(y_train)
print(X_test)
print(y_test)

print("Unique Emotions in Training Set:", y_train.unique())
print("Unique Emotions in Testing Set:", y_test.unique())
# Out:
# Training Data Size: 16000
# Testing Data Size: 2000
# 0                                  i didnt feel humiliated
# 1        i can go from feeling so hopeless to so damned...
# 2         im grabbing a minute to post i feel greedy wrong
# 3        i am ever feeling nostalgic about the fireplac...
# 4                                     i am feeling grouchy
#                                ...
# 15995    i just had a very brief time in the beanbag an...
# 15996    i am now turning and i feel pathetic that i am...
# 15997                       i feel strong and good overall
# 15998    i feel like this was such a rude comment and i...
# 15999    i know a lot but i feel so stupid because i ca...
# Name: text, Length: 16000, dtype: object
# 0        0
# 1        0
# 2        3
# 3        2
# 4        3
#         ..
# 15995    0
# 15996    0
# 15997    1
# 15998    3
# 15999    0
# Name: label, Length: 16000, dtype: int64
# 0       im feeling rather rotten so im not very ambiti...
# ...

# %%
#training the model
vectorizer_emotion = TfidfVectorizer()
X_train_vec = vectorizer_emotion.fit_transform(X_train)
clf_emotion = SVC(kernel='linear')
clf_emotion.fit(X_train_vec, y_train)
# Out:
# SVC(kernel='linear')

# %%
X_test_vec = vectorizer_emotion.transform(X_test)
predicted_emotion = clf_emotion.predict(X_test_vec)
print("Predicted Emotions for Test Set:", predicted_emotion[:5])
print("True Emotions for Test Set:", y_test[:5])
# Out:
# Predicted Emotions for Test Set: [0 0 0 1 0]
# True Emotions for Test Set: 0    0
# 1    0
# 2    0
# 3    1
# 4    0
# Name: label, dtype: int64

# %%
#checking the accuracy of the model
from sklearn.metrics import accuracy_score, classification_report
accuracy = accuracy_score(y_test, predicted_emotion)
print("Accuracy of Emotion Classification:", accuracy)
print("Classification Report:\n", classification_report(y_test, predicted_emotion))
# Out:
# Accuracy of Emotion Classification: 0.8855
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.92      0.93       581
#            1       0.88      0.95      0.91       695
#            2       0.82      0.67      0.74       159
#            3       0.89      0.88      0.88       275
#            4       0.85      0.85      0.85       224
#            5       0.76      0.56      0.64        66
#
#     accuracy                           0.89      2000
#    macro avg       0.85      0.81      0.83      2000
# weighted avg       0.88      0.89      0.88      2000

# %%
# now testing some custom sentences from my side
custom_sentences = [
    "i am so happy to see you",
    "this is the worst day of my life damn so  bad",
    "i feel so excited about the upcoming event",
    "you are really annoying me right now",
    "i am so sad about the news i heard today",
    "ive been feeling a little burdened lately wasnt sure why that was",
    "i am sorry for u my dear friend",
    "never show me your face again you are so annoying i am mad at you",
    "i am so grateful for your help",
    "i am so excited about the new project",
    "i am so surprised by the news",
    "i am so scared about the future",
    "i hate this weather",
    "i am so angry at you",]
custom_sentences_vec = vectorizer_emotion.transform(custom_sentences)
predicted_custom_emotions = clf_emotion.predict(custom_sentences_vec)
print("Predicted Emotions for Custom Sentences:", predicted_custom_emotions)
# Out:
# Predicted Emotions for Custom Sentences: [1 0 1 1 0 0 0 3 1 1 5 4 0 3]

# %%
#values including sadness (0), joy (1), love (2), anger (3), fear (4) surprise (5).

# %%
# now lets try some other models
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=7)
knn.fit(X_train_vec, y_train)
knn_predicted_emotion = knn.predict(X_test_vec)
print("KNN Predicted Emotions for Test Set:", knn_predicted_emotion[:5])
# Evaluating the KNN model
accuracy_knn = accuracy_score(y_test, knn_predicted_emotion)
print("KNN Accuracy of Emotion Classification:", accuracy_knn)

#this accuracy is lesser than SVC model even by trying changing the n_neighbors value
# Out:
# KNN Predicted Emotions for Test Set: [0 0 1 0 0]
# KNN Accuracy of Emotion Classification: 0.7265

# %%
# tryinng decision tree classifier
from sklearn.tree import DecisionTreeClassifier

tree = DecisionTreeClassifier(max_depth=100000)
tree.fit(X_train_vec, y_train)
y_pred_tree = tree.predict(X_test_vec)
print("Decision Tree Predicted Emotions for Test Set:", y_pred_tree[:5])
# Evaluating the Decision Tree model
accuracy_tree = accuracy_score(y_test, y_pred_tree)
print("Decision Tree Accuracy of Emotion Classification:", accuracy_tree)
# Out:
# Decision Tree Predicted Emotions for Test Set: [0 0 0 4 0]
# Decision Tree Accuracy of Emotion Classification: 0.8485

# %%
#naive bayes classifier
from sklearn.naive_bayes import GaussianNB
nb = GaussianNB()
nb.fit(X_train_vec.toarray(), y_train)
y_pred_nb = nb.predict(X_test_vec.toarray())
print("Accuracy:", accuracy_score(y_test, y_pred_nb))
# Out:
# Accuracy: 0.349

# %%
#gradient boosting classifier
from sklearn.ensemble import GradientBoostingClassifier
gb = GradientBoostingClassifier(n_estimators=100, learning_rate=1.0, max_depth=100, random_state=0)
gb.fit(X_train_vec, y_train)
y_pred_gb = gb.predict(X_test_vec)
print("Gradient Boosting Predicted Emotions for Test Set:", y_pred_gb[:5])
# Evaluating the Gradient Boosting model
accuracy_gb = accuracy_score(y_test, y_pred_gb)
print("Gradient Boosting Accuracy of Emotion Classification:", accuracy_gb)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[80], line 4
#       2 from sklearn.ensemble import GradientBoostingClassifier
#       3 gb = GradientBoostingClassifier(n_estimators=100, learning_rate=1.0, max_depth=100, random_state=0)
# ----> 4 gb.fit(X_train_vec, y_train)
#       5 y_pred_gb = gb.predict(X_test_vec)
#       6 print("Gradient Boosting Predicted Emotions for Test Set:", y_pred_gb[:5])
#
# File ~/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# ...

# %%
print(X_train_vec[0])
# Out:
#   (np.int32(0), np.int32(3615))	0.5951235084078971
#   (np.int32(0), np.int32(4924))	0.16379156905484632
#   (np.int32(0), np.int32(6429))	0.7867657412767967

# %%
# now trying CountVectorizer() instead of TfidfVectorizer()
vectorizer = CountVectorizer()
X_train_count = vectorizer.fit_transform(X_train)
clf_count = SVC(kernel='linear')
clf_count.fit(X_train_count, y_train)
X_test_count = vectorizer.transform(X_test)
predicted_emotion_count = clf_count.predict(X_test_count)
print("Predicted Emotions for Test Set using CountVectorizer:", predicted_emotion_count[:5])
# Evaluating the CountVectorizer model
accuracy_count = accuracy_score(y_test, predicted_emotion_count)
print("Accuracy of Emotion Classification using CountVectorizer:", accuracy_count)
# Out:
# Predicted Emotions for Test Set using CountVectorizer: [0 0 0 1 0]
# Accuracy of Emotion Classification using CountVectorizer: 0.8755

# %%
# now by trying by removing stop words and punctuation from the training data
import re
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

#removing punctuation and converting to lowercase not required because data is of that form only
# Tokenizing and removing stopwords
X_train_cleaned = [' '.join([word for word in word_tokenize(text.lower()) if word not in stopwords.words('english')]) for text in X_train]
X_test_cleaned = [' '.join([word for word in word_tokenize(text.lower()) if word not in stopwords.words('english')]) for text in X_test]

print("First training text:", X_train.iloc[0])  # Original first training text
print("Cleaned first training text:", X_train_cleaned[0])  # Cleaned first training text (Removed stopwords)
# Feature Extraction using CountVectorizer
vectorizer_cleaned = CountVectorizer()
X_train_count_cleaned = vectorizer_cleaned.fit_transform(X_train_cleaned)
clf_count_cleaned = SVC(kernel='linear')
clf_count_cleaned.fit(X_train_count_cleaned, y_train)
# Out:
# First training text: i didnt feel humiliated
# Cleaned first training text: didnt feel humiliated
# SVC(kernel='linear')

# %%
#now transforming the test data
X_test_count_cleaned = vectorizer_cleaned.transform(X_test_cleaned)
predicted_emotion_count_cleaned = clf_count_cleaned.predict(X_test_count_cleaned)
print("Predicted Emotions for Test Set using CountVectorizer with Cleaned Data:", predicted_emotion_count_cleaned[:5])
# Evaluating the CountVectorizer model with cleaned data
accuracy_count_cleaned = accuracy_score(y_test, predicted_emotion_count_cleaned)
print("Accuracy of Emotion Classification using CountVectorizer with Cleaned Data:", accuracy_count_cleaned)
# This accuracy is better than the previous CountVectorizer model without cleaning the data
# Out:
# Predicted Emotions for Test Set using CountVectorizer with Cleaned Data: [0 0 0 1 0]
# Accuracy of Emotion Classification using CountVectorizer with Cleaned Data: 0.876

# %%
#now trying with the cleaned data using TfidfVectorizer
X_train_tfidf_cleaned = vectorizer_emotion.fit_transform(X_train_cleaned)
clf_tfidf_cleaned = SVC(kernel='linear')
clf_tfidf_cleaned.fit(X_train_tfidf_cleaned, y_train)
# Out:
# SVC(kernel='linear')

# %%
X_test_tfidf_cleaned = vectorizer_emotion.transform(X_test_cleaned)
predicted_emotion_tfidf_cleaned = clf_tfidf_cleaned.predict(X_test_tfidf_cleaned)
print("Predicted Emotions for Test Set using TfidfVectorizer with Cleaned Data:", predicted_emotion_tfidf_cleaned[:5])
# Evaluating the TfidfVectorizer model with cleaned data
accuracy_tfidf_cleaned = accuracy_score(y_test, predicted_emotion_tfidf_cleaned)
print("Accuracy of Emotion Classification using TfidfVectorizer with Cleaned Data:", accuracy_tfidf_cleaned)
# Out:
# Predicted Emotions for Test Set using TfidfVectorizer with Cleaned Data: [0 0 0 1 0]
# Accuracy of Emotion Classification using TfidfVectorizer with Cleaned Data: 0.8845

# %%
import pandas as pd
# now lets try checking the accuracy of the model on the validation set
df_train=pd.read_csv('./dataset3/validation.csv')
X_val = df_train.iloc[:, 0]  # get all the sentences
y_val = df_train.iloc[:, 1]  # get the emotions associated with the sentences
print("Validation Data Size:", len(X_val))
print("Unique Emotions in Validation Set:", y_val.unique())
X_val_cleaned = [' '.join([word for word in word_tokenize(text.lower()) if word not in stopwords.words('english')]) for text in X_val]
# Out:
# Validation Data Size: 2000
# Unique Emotions in Validation Set: [0 2 3 1 4 5]

# %%
X_val_tfidf_cleaned = vectorizer_emotion.transform(X_val_cleaned)
predicted_emotion_val_cleaned = clf_tfidf_cleaned.predict(X_val_tfidf_cleaned)

# %%
print("Predicted Emotions for Validation Set using TfidfVectorizer with Cleaned Data:", predicted_emotion_val_cleaned[:5])
# Evaluating the TfidfVectorizer model with cleaned data on validation set
accuracy_val_cleaned = accuracy_score(y_val, predicted_emotion_val_cleaned)
print("Accuracy of Emotion Classification using TfidfVectorizer with Cleaned Data on Validation Set:", accuracy_val_cleaned)
# Out:
# Predicted Emotions for Validation Set using TfidfVectorizer with Cleaned Data: [0 0 2 3 1]
# Accuracy of Emotion Classification using TfidfVectorizer with Cleaned Data on Validation Set: 0.8895

# %%
# now checking accuracy of the model on validation set without cleaning the data
# Fit the vectorizer only on the training data, then transform both train and val
X_train_vec = vectorizer_emotion.fit_transform(X_train)
X_val_vec = vectorizer_emotion.transform(X_val)
# training again the model on the training data
clf_emotion2 = SVC(kernel='linear')
clf_emotion2.fit(X_train_vec, y_train)
predicted_emotion_val = clf_emotion2.predict(X_val_vec)
print("Predicted Emotions for Validation Set using TfidfVectorizer without Cleaned Data:", predicted_emotion_val[:5])
# Evaluating the TfidfVectorizer model without cleaned data on validation set
accuracy_val = accuracy_score(y_val, predicted_emotion_val)
print("Accuracy of Emotion Classification using TfidfVectorizer without Cleaned Data on Validation Set:", accuracy_val)
# Out:
# Predicted Emotions for Validation Set using TfidfVectorizer without Cleaned Data: [0 0 2 3 1]
# Accuracy of Emotion Classification using TfidfVectorizer without Cleaned Data on Validation Set: 0.889

# %%
#therefore going with the model trained on cleaned data using TfidfVectorizer and using SVC classifier
# Saving the model and vectorizer for future use

import pickle
# Save the trained model

filename = 'emotion_detector.pkl'

# Save model (serialize)
pickle.dump(clf_tfidf_cleaned, open(filename, 'wb'))

# Load model (de-serialize)
pickle.load(open(filename, 'rb'))
# Out:
# SVC(kernel='linear')

# %%
import pickle
from sklearn.feature_extraction.text import TfidfVectorizer

#also need to save the vectorizer
vectorizer_filename = 'vectorizer_emotion.pkl'

# vectorizer_emotion = TfidfVectorizer()

# Save vectorizer (serialize)
pickle.dump(vectorizer_emotion, open(vectorizer_filename, 'wb'))
# Load vectorizer (de-serialize)
pickle.load(open(vectorizer_filename, 'rb'))
# Out:
# TfidfVectorizer()

# %%
texts = ["i am feeling so happy today","i am so angry at you","i am so sad about the news i heard today"]

# Clean the text (remove stopwords, lowercase) - same as training
text_cleaned = [' '.join([word for word in word_tokenize(text.lower()) if word not in stopwords.words('english')]) for text in texts]
# text_cleaned = [' '.join([word for word in word_tokenize(text.lower()) if word not in stopwords.words('english')])]

# Use the same vectorizer and classifier as trained on cleaned data
prediction = clf_tfidf_cleaned.predict(vectorizer_emotion.transform(text_cleaned))
print(f"Prediction: ", prediction)
# Out:
# Prediction:  [1 3 0]

# %%
#values including sadness (0), joy (1), love (2), anger (3), fear (4) surprise (5).
